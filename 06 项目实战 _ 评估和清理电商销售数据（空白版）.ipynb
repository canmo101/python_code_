# %% [markdown]
# # 项目：评估和清理英国电商公司销售数据

# %% [markdown]
# ## 分析目标

# %% [markdown]
# 此数据分析的目的是，根据市场销售数据，挖掘畅销产品，以便制定更有效的市场策略来提升营收。
#
# 本实战项目的目的在于练习评估数据干净和整洁度，并且基于评估结果，对数据进行清洗，从而得到可供下一步分析的数据。

# %% [markdown]
# ## 简介

# %% [markdown]
# 原始数据集记录了一家英国在线零售公司在2010年12月1日至2011年12月9日期间的所有交易情况，涵盖了该公司在全球不同国家和地区的业务数据。该公司主要销售覆盖各个场景的礼品，包括但不限于生日礼品、结婚纪念品、圣诞礼品等等。该公司的客户群体主要包括批发商和个人消费者，其中批发商占据了相当大的比例。

# %% [markdown]
# 数据每列的含义如下：
# - `InvoiceNo`: 发票号码。6位数，作为交易的唯一标识符。如果这个代码以字母“c”开头，表示这笔交易被取消。
# - `StockCode`: 产品代码。5位数，作为产品的唯一标识符。
# - `Description`: 产品名称。
# - `Quantity`: 产品在交易中的数量。
# - `InvoiceDate`: 发票日期和时间。交易发生的日期和时间。
# - `UnitPrice`: 单价。价格单位为英镑（£）。
# - `CustomerID`: 客户编号。5位数，作为客户的唯一标识符。
# - `Country`: 国家名称。客户所居住的国家的名称。

# %% [markdown]
# ## 读取数据

# %%
import pandas as pd

# %%
load_date = pd.read_csv("e_commerce.csv")
load_date.head()
load_date.sample(20)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 440269    574529     23490    T-LIGHT HOLDER HANGING LOVE BIRD         2
# 489671    578022     22405       MONEY BOX POCKET MONEY DESIGN         1
# 122817    546888     22365           DOORMAT RESPECTABLE HOUSE         1
# 510175    579432     85203    HANGING WOOD AND FELT BUTTERFLY          8
# 160820    550470     22666     RECIPE BOX PANTRY YELLOW DESIGN         2
# 5554      536865     20723            STRAWBERRY CHARLOTTE BAG         2
# 79623     542998    85039a  SET/4 RED MINI ROSE CANDLE IN BOWL         1
# 379624    569700     22336       DOVE DECORATION PAINTED ZINC          2
# 380046    569727     23395      BELLE JARDINIERE CUSHION COVER         4
# 341506    566757     22558     CLOTHES PEGS RETROSPOT PACK 24          2
# 286933    562046     21559   STRAWBERRY LUNCH BOX WITH CUTLERY         6
# 389448    570467     37495      FAIRY CAKE BIRTHDAY CANDLE SET         4
# ...

# %%
load_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
load_date["Country"].value_counts()
# Out:
# Country
# United Kingdom          495266
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# China                      288
# Singapore                  229
# USA                        218
# UK                         211
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# ...

# %%
load_date.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ## 评估数据

# %% [markdown]
# ## 结构正确
#
# ## 内容有问题
# Description 有空值 产品名称缺失 有影响
# CustomerID  有空值 客户id缺失不影响
#
# InvoiceDate  格式不对  日期格式
# CustomerID  格式不对    字符串
# StockCode   有6位数
# Country    有指向相同内容不同
#
# Quantity	UnitPrice  数量和单价有负值情况

# %%
load_date[load_date["Description"].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 622       536414     22139         NaN        56  12/1/2010 11:52        0.0
# 1970      536545     21134         NaN         1  12/1/2010 14:32        0.0
# 1971      536546     22145         NaN         1  12/1/2010 14:33        0.0
# 1972      536547     37509         NaN         1  12/1/2010 14:33        0.0
# 1987      536549    85226A         NaN         1  12/1/2010 14:34        0.0
# ...          ...       ...         ...       ...              ...        ...
# 535322    581199     84581         NaN        -2  12/7/2011 18:26        0.0
# 535326    581203     23406         NaN        15  12/7/2011 18:31        0.0
# 535332    581209     21620         NaN         6  12/7/2011 18:35        0.0
# 536981    581234     72817         NaN        27  12/8/2011 10:33        0.0
# 538554    581408     85175         NaN        20  12/8/2011 14:06        0.0
#
#         CustomerID         Country
# ...

# %% [markdown]
# 从输出结果来看，这些缺失Description的交易数据，UnitPrice都为0

# %%
load_date[(load_date["Description"].isnull())&(load_date["UnitPrice"] != 0)]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# 可以剔除

# %%
load_date[load_date["Quantity"]<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# 代表退货

# %%
load_date[load_date["UnitPrice"]<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity      InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1  8/12/2011 14:51
# 299984   A563187         B  Adjust bad debt         1  8/12/2011 14:52
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# 坏帐处理

# %%
load_date[load_date["StockCode"].str.contains('[A-Za-z]')].sample(20)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 260456    559812    84519A     TOMATO CHARLIE+LOLA COASTER SET         2
# 228148    556916    85123A  WHITE HANGING HEART T-LIGHT HOLDER         2
# 432649    573878    17091J              VANILLA INCENSE IN TIN        36
# 12741     537395    84849B              FAIRY SOAP SOAP HOLDER         2
# 53315     540832    48173c                DOORMAT BLACK FLOCK          1
# 37302     539456    85135C            RED DRAGONFLY HELICOPTER         1
# 508459    579196       DOT                      DOTCOM POSTAGE         1
# 55061     540977    90014A           SILVER/MOP ORBIT NECKLACE         1
# 1144      536528    85049E           SCANDINAVIAN REDS RIBBONS         1
# 125073    547017    46776B        WOVEN BERRIES CUSHION COVER          2
# 448351    575049      POST                             POSTAGE         3
# 167454    550987    90214O           LETTER "O" BLING KEY RING         1
# ...

# %% [markdown]
# 大部分是消费品的细分
# 但是有post是邮费

# %%
load_date[~load_date["StockCode"].str.contains('\\d')].sample(20)    #非纯数字的
# Out:
#        InvoiceNo  StockCode     Description  Quantity       InvoiceDate  \
# 135861   C547915          M          Manual        -1   3/28/2011 12:37
# 96695    C544580          S         SAMPLES        -1   2/21/2011 14:25
# 312087    564337       POST         POSTAGE         1   8/24/2011 14:40
# 52368     540769       POST         POSTAGE         1   1/11/2011 10:38
# 219972    556108        DOT  DOTCOM POSTAGE         1    6/8/2011 17:59
# 242445   C558347          S         SAMPLES        -1   6/28/2011 14:47
# 380051    569727       POST         POSTAGE         2    10/6/2011 9:37
# 505695    579094       POST         POSTAGE         8  11/28/2011 10:56
# 343512    566952        DOT  DOTCOM POSTAGE         1   9/15/2011 16:37
# 358250   C568138          M          Manual      -144   9/25/2011 10:43
# 43703    C540118  AMAZONFEE      AMAZON FEE        -1     1/5/2011 9:57
# 256649    559504          M          Manual         2    7/8/2011 15:16
# ...

# %% [markdown]
# Manual  自动   无法理解
# DOTCOM POSTAGE 、POSTAGE	 运费
# SAMPLES   样品
# AMAZON FEE  免费？赠品

# %%
load_date[load_date["Description"] == "Manual"]
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 2239      536569         M      Manual         1  12/1/2010 15:35       1.25
# 2250      536569         M      Manual         1  12/1/2010 15:35      18.95
# 5684      536865         M      Manual         1  12/3/2010 11:28       2.55
# 6798      536981         M      Manual         2  12/3/2010 14:26       0.85
# 7976      537077         M      Manual        12  12/5/2010 11:59       0.42
# ...          ...       ...         ...       ...              ...        ...
# 531432    580956         M      Manual         4  12/6/2011 14:23       1.25
# 533082   C581009         M      Manual        -1   12/7/2011 9:15     125.00
# 534308   C581145         M      Manual        -1  12/7/2011 13:48       9.95
# 538321    581405         M      Manual         3  12/8/2011 13:50       0.42
# 541541   C581499         M      Manual        -1  12/9/2011 10:28     224.69
#
#         CustomerID         Country
# ...

# %% [markdown]
# ## 清理数据

# %% [markdown]
# 改数据结构
# InvoiceDate  格式不对  日期格式
# CustomerID  格式不对    字符串

# %% [markdown]
# 删除无用数据
# Description 有空值 产品名称缺失 有影响
# Quantity	UnitPrice  数量和单价有负值情况

# %% [markdown]
# Country变量值"USA"替换为"United States"

# %%
复制df表格

# %%
cleaned_data = load_date.copy()
cleaned_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
cleaned_data["InvoiceDate"] = pd.to_datetime(cleaned_data["InvoiceDate"])

# %%
cleaned_data["CustomerID"] = cleaned_data["CustomerID"].astype(str)
cleaned_data["CustomerID"] =cleaned_data["CustomerID"].str.slice(0, -2)
cleaned_data["CustomerID"]
# Out:
# 0         17850
# 1         17850
# 2         17850
# 3         17850
# 4         17850
#           ...
# 541904    12680
# 541905    12680
# 541906    12680
# 541907    12680
# 541908    12680
# Name: CustomerID, Length: 541909, dtype: object

# %% [markdown]
# "CustomerID",变成字符串，且去掉小数点后内容

# %%
cleaned_data = cleaned_data.dropna(subset=["Description"])
cleaned_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %% [markdown]
# 删除Description的缺失值

# %%
cleaned_data["Description"].isnull().sum()
# Out:
# 0

# %% [markdown]
# 检查Description 是否还有缺失值

# %%
cleaned_data = cleaned_data[cleaned_data["Quantity"]>=0]
cleaned_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
cleaned_data = cleaned_data[cleaned_data["UnitPrice"]>=0]
cleaned_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %% [markdown]
# 删除UnitPrice、Quantity 负值情况

# %%
cleaned_data["Country"] = cleaned_data["Country"].replace("USA","United States")   #数组

# %%
len(cleaned_data[cleaned_data["Country"] == "USA"])
# Out:
# 0

# %%
cleaned_data["Country"] = cleaned_data["Country"].replace(["UK","U.K."],"United Kingdom")   #列表

# %%
len(cleaned_data[cleaned_data["Country"] == "U.K."])
# Out:
# 0

# %%
cleaned_data["Country"] = cleaned_data["Country"].replace({"UK": "United Kingdom", "U.K.": "United Kingdom"})   #词典

# %%
len(cleaned_data[cleaned_data["UnitPrice"] < 0])
# Out:
# 0

# %% [markdown]
# ## 保存清理后的数据

# %%
cleaned_data.to_csv("e_clenede.csv", index=False)     #index  序列号取消
